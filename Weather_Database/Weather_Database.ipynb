# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
import time
from datetime import datetime
# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 731

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
         # Description    
        city_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | carnarvon
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | faanui
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | kadom
# Processing Record 6 of Set 1 | pangnirtung
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | sulangan
# Processing Record 9 of Set 1 | avera
# Processing Record 10 of Set 1 | dubai
# Processing Record 11 of Set 1 | kodiak
# Processing Record 12 of Set 1 | cayenne
# Processing Record 13 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 1 | mogadishu
# Processing Record 15 of Set 1 | tiksi
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | watsa
# Processing Record 18 of Set 1 | kaitangata
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | ostrovnoy
# Processing Record 23 of Set 1 | betsiamites
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | broken hill
# Processing Record 28 of Set 1 | ilulissat
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | mahebourg
# Processing Record 31 of Set 1 | linxia
# Processing Record 32 of Set 1 | jamestown
# Processing Record 33 of Set 1 | chuy
# Processing Record 34 of Set 1 | okhotsk
# Processing Record 35 of Set 1 | kavaratti
# Processing Record 36 of Set 1 | pevek
# Processing Record 37 of Set 1 | paraiso
# Processing Record 38 of Set 1 | cidreira
# Processing Record 39 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | khatanga
# Processing Record 42 of Set 1 | qaanaaq
# Processing Record 43 of Set 1 | chokurdakh
# Processing Record 44 of Set 1 | amalapuram
# Processing Record 45 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 1 | hobart
# Processing Record 47 of Set 1 | katsuura
# Processing Record 48 of Set 1 | hilo
# Processing Record 49 of Set 1 | vaini
# Processing Record 50 of Set 1 | mahanje
# Processing Record 1 of Set 2 | goundi
# Processing Record 2 of Set 2 | melfort
# Processing Record 3 of Set 2 | puerto ayora
# Processing Record 4 of Set 2 | tanout
# Processing Record 5 of Set 2 | pangody
# Processing Record 6 of Set 2 | puerto narino
# Processing Record 7 of Set 2 | vanavara
# Processing Record 8 of Set 2 | dikson
# Processing Record 9 of Set 2 | nivala
# Processing Record 10 of Set 2 | qaqortoq
# Processing Record 11 of Set 2 | yellowknife
# Processing Record 12 of Set 2 | torbay
# Processing Record 13 of Set 2 | balabac
# Processing Record 14 of Set 2 | port hedland
# Processing Record 15 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 16 of Set 2 | fort nelson
# Processing Record 17 of Set 2 | saint george
# Processing Record 18 of Set 2 | kaoma
# Processing Record 19 of Set 2 | san juan
# Processing Record 20 of Set 2 | cockburn town
# Processing Record 21 of Set 2 | nanortalik
# Processing Record 22 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 2 | pantai remis
# Processing Record 24 of Set 2 | dinsor
# City not found. Skipping...
# Processing Record 25 of Set 2 | sioux lookout
# Processing Record 26 of Set 2 | saint-francois
# Processing Record 27 of Set 2 | enid
# Processing Record 28 of Set 2 | port elizabeth
# Processing Record 29 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 2 | laguna
# Processing Record 31 of Set 2 | turhal
# Processing Record 32 of Set 2 | bethel
# Processing Record 33 of Set 2 | kununurra
# Processing Record 34 of Set 2 | taoudenni
# Processing Record 35 of Set 2 | barrow
# Processing Record 36 of Set 2 | skibbereen
# Processing Record 37 of Set 2 | mezen
# Processing Record 38 of Set 2 | tasiilaq
# Processing Record 39 of Set 2 | iriron
# City not found. Skipping...
# Processing Record 40 of Set 2 | tessalit
# Processing Record 41 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 2 | castro
# Processing Record 43 of Set 2 | husavik
# Processing Record 44 of Set 2 | mataura
# Processing Record 45 of Set 2 | bambous virieux
# Processing Record 46 of Set 2 | umm lajj
# Processing Record 47 of Set 2 | hithadhoo
# Processing Record 48 of Set 2 | iqaluit
# Processing Record 49 of Set 2 | cururupu
# Processing Record 50 of Set 2 | kisangani
# Processing Record 1 of Set 3 | hopelchen
# Processing Record 2 of Set 3 | meulaboh
# Processing Record 3 of Set 3 | lebu
# Processing Record 4 of Set 3 | tuktoyaktuk
# Processing Record 5 of Set 3 | chandler
# Processing Record 6 of Set 3 | puro
# Processing Record 7 of Set 3 | airai
# Processing Record 8 of Set 3 | samana
# Processing Record 9 of Set 3 | taltal
# Processing Record 10 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 3 | cherskiy
# Processing Record 12 of Set 3 | lorengau
# Processing Record 13 of Set 3 | saint-philippe
# Processing Record 14 of Set 3 | togur
# Processing Record 15 of Set 3 | bubaque
# Processing Record 16 of Set 3 | abu samrah
# Processing Record 17 of Set 3 | caravelas
# Processing Record 18 of Set 3 | tuatapere
# Processing Record 19 of Set 3 | nishihara
# Processing Record 20 of Set 3 | caucasia
# Processing Record 21 of Set 3 | marawi
# Processing Record 22 of Set 3 | mount pleasant
# Processing Record 23 of Set 3 | arraial do cabo
# Processing Record 24 of Set 3 | saryshagan
# City not found. Skipping...
# Processing Record 25 of Set 3 | sur
# Processing Record 26 of Set 3 | isiro
# Processing Record 27 of Set 3 | longyearbyen
# Processing Record 28 of Set 3 | ilebo
# Processing Record 29 of Set 3 | morondava
# Processing Record 30 of Set 3 | port blair
# Processing Record 31 of Set 3 | clyde river
# Processing Record 32 of Set 3 | talnakh
# Processing Record 33 of Set 3 | afyonkarahisar
# Processing Record 34 of Set 3 | mar del plata
# Processing Record 35 of Set 3 | adrar
# Processing Record 36 of Set 3 | mlandizi
# Processing Record 37 of Set 3 | vardo
# Processing Record 38 of Set 3 | lucapa
# Processing Record 39 of Set 3 | busselton
# Processing Record 40 of Set 3 | joao pinheiro
# Processing Record 41 of Set 3 | butaritari
# Processing Record 42 of Set 3 | cabo san lucas
# Processing Record 43 of Set 3 | seoul
# Processing Record 44 of Set 3 | ixtapa
# Processing Record 45 of Set 3 | kundiawa
# Processing Record 46 of Set 3 | georgetown
# Processing Record 47 of Set 3 | ponta do sol
# Processing Record 48 of Set 3 | vao
# Processing Record 49 of Set 3 | srednekolymsk
# Processing Record 50 of Set 3 | buritizeiro
# Processing Record 1 of Set 4 | saint-pierre
# Processing Record 2 of Set 4 | murud
# Processing Record 3 of Set 4 | karamea
# City not found. Skipping...
# Processing Record 4 of Set 4 | aksarka
# Processing Record 5 of Set 4 | choma
# Processing Record 6 of Set 4 | kruisfontein
# Processing Record 7 of Set 4 | talaya
# Processing Record 8 of Set 4 | antofagasta
# Processing Record 9 of Set 4 | liuhe
# Processing Record 10 of Set 4 | bilma
# Processing Record 11 of Set 4 | khani
# Processing Record 12 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 4 | severo-kurilsk
# Processing Record 14 of Set 4 | chapais
# Processing Record 15 of Set 4 | poronaysk
# Processing Record 16 of Set 4 | manga
# Processing Record 17 of Set 4 | visnes
# Processing Record 18 of Set 4 | avarua
# Processing Record 19 of Set 4 | den helder
# Processing Record 20 of Set 4 | kondopoga
# Processing Record 21 of Set 4 | pafos
# Processing Record 22 of Set 4 | acapulco
# Processing Record 23 of Set 4 | noumea
# Processing Record 24 of Set 4 | nara
# Processing Record 25 of Set 4 | neiafu
# Processing Record 26 of Set 4 | viedma
# Processing Record 27 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 4 | bambanglipuro
# Processing Record 29 of Set 4 | mawlaik
# Processing Record 30 of Set 4 | manono
# Processing Record 31 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 4 | sabha
# Processing Record 34 of Set 4 | salalah
# Processing Record 35 of Set 4 | necochea
# Processing Record 36 of Set 4 | kahului
# Processing Record 37 of Set 4 | kutum
# Processing Record 38 of Set 4 | hobyo
# Processing Record 39 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 40 of Set 4 | tawkar
# City not found. Skipping...
# Processing Record 41 of Set 4 | san quintin
# Processing Record 42 of Set 4 | new norfolk
# Processing Record 43 of Set 4 | xuddur
# Processing Record 44 of Set 4 | esperance
# Processing Record 45 of Set 4 | gubin
# Processing Record 46 of Set 4 | mount gambier
# Processing Record 47 of Set 4 | nicoya
# Processing Record 48 of Set 4 | berlevag
# Processing Record 49 of Set 4 | cheney
# Processing Record 50 of Set 4 | lazaro cardenas
# Processing Record 1 of Set 5 | oktyabrskoye
# Processing Record 2 of Set 5 | wollongong
# Processing Record 3 of Set 5 | valparaiso
# Processing Record 4 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 5 | tabas
# Processing Record 6 of Set 5 | north myrtle beach
# Processing Record 7 of Set 5 | college
# Processing Record 8 of Set 5 | sao filipe
# Processing Record 9 of Set 5 | san juan de colon
# Processing Record 10 of Set 5 | grong
# Processing Record 11 of Set 5 | tungor
# Processing Record 12 of Set 5 | kralendijk
# Processing Record 13 of Set 5 | upernavik
# Processing Record 14 of Set 5 | tura
# Processing Record 15 of Set 5 | ust-barguzin
# Processing Record 16 of Set 5 | brownsburg
# Processing Record 17 of Set 5 | ola
# Processing Record 18 of Set 5 | muroran
# Processing Record 19 of Set 5 | provost
# Processing Record 20 of Set 5 | mumford
# Processing Record 21 of Set 5 | bengkulu
# Processing Record 22 of Set 5 | kudahuvadhoo
# Processing Record 23 of Set 5 | ossora
# Processing Record 24 of Set 5 | chagoda
# Processing Record 25 of Set 5 | nobres
# Processing Record 26 of Set 5 | homer
# Processing Record 27 of Set 5 | sattahip
# Processing Record 28 of Set 5 | chake chake
# Processing Record 29 of Set 5 | arlit
# Processing Record 30 of Set 5 | ji-parana
# City not found. Skipping...
# Processing Record 31 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 32 of Set 5 | merauke
# Processing Record 33 of Set 5 | luan
# Processing Record 34 of Set 5 | loralai
# Processing Record 35 of Set 5 | mount isa
# Processing Record 36 of Set 5 | kenai
# Processing Record 37 of Set 5 | springbok
# Processing Record 38 of Set 5 | chom bung
# City not found. Skipping...
# Processing Record 39 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 40 of Set 5 | bonthe
# Processing Record 41 of Set 5 | dali
# Processing Record 42 of Set 5 | kokoda
# Processing Record 43 of Set 5 | fairbanks
# Processing Record 44 of Set 5 | burns lake
# Processing Record 45 of Set 5 | northam
# Processing Record 46 of Set 5 | malgrat de mar
# Processing Record 47 of Set 5 | sola
# Processing Record 48 of Set 5 | hasaki
# Processing Record 49 of Set 5 | vuktyl
# Processing Record 50 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 6 | jaipur hat
# City not found. Skipping...
# Processing Record 2 of Set 6 | boyolangu
# Processing Record 3 of Set 6 | sheridan
# Processing Record 4 of Set 6 | holme
# Processing Record 5 of Set 6 | norman wells
# Processing Record 6 of Set 6 | chiang klang
# Processing Record 7 of Set 6 | gachala
# Processing Record 8 of Set 6 | jizan
# Processing Record 9 of Set 6 | saskylakh
# Processing Record 10 of Set 6 | kashan
# Processing Record 11 of Set 6 | nuuk
# Processing Record 12 of Set 6 | coquimbo
# Processing Record 13 of Set 6 | bandarbeyla
# Processing Record 14 of Set 6 | coahuayana
# Processing Record 15 of Set 6 | narsaq
# Processing Record 16 of Set 6 | hofn
# Processing Record 17 of Set 6 | carbonia
# Processing Record 18 of Set 6 | ormara
# Processing Record 19 of Set 6 | mugur-aksy
# Processing Record 20 of Set 6 | vila velha
# Processing Record 21 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 22 of Set 6 | geraldton
# Processing Record 23 of Set 6 | najran
# Processing Record 24 of Set 6 | klaksvik
# Processing Record 25 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 6 | asmar
# Processing Record 27 of Set 6 | brotas
# Processing Record 28 of Set 6 | ambon
# Processing Record 29 of Set 6 | pontianak
# Processing Record 30 of Set 6 | ribeira grande
# Processing Record 31 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 6 | nome
# Processing Record 33 of Set 6 | chhatak
# Processing Record 34 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 6 | sabang
# Processing Record 36 of Set 6 | flic en flac
# Processing Record 37 of Set 6 | brigantine
# Processing Record 38 of Set 6 | nikolskoye
# Processing Record 39 of Set 6 | dingle
# Processing Record 40 of Set 6 | akureyri
# Processing Record 41 of Set 6 | porgera
# Processing Record 42 of Set 6 | sinnamary
# Processing Record 43 of Set 6 | bukama
# Processing Record 44 of Set 6 | belawan
# Processing Record 45 of Set 6 | kampene
# Processing Record 46 of Set 6 | west bay
# Processing Record 47 of Set 6 | rostovka
# Processing Record 48 of Set 6 | derzhavinsk
# Processing Record 49 of Set 6 | labuhan
# Processing Record 50 of Set 6 | jalu
# Processing Record 1 of Set 7 | kelo
# Processing Record 2 of Set 7 | hervey bay
# Processing Record 3 of Set 7 | port lincoln
# Processing Record 4 of Set 7 | linhares
# Processing Record 5 of Set 7 | naze
# Processing Record 6 of Set 7 | east london
# Processing Record 7 of Set 7 | vila franca do campo
# Processing Record 8 of Set 7 | bandar-e lengeh
# Processing Record 9 of Set 7 | iquitos
# Processing Record 10 of Set 7 | pisco
# Processing Record 11 of Set 7 | saldanha
# Processing Record 12 of Set 7 | austin
# Processing Record 13 of Set 7 | guerrero negro
# Processing Record 14 of Set 7 | qasigiannguit
# Processing Record 15 of Set 7 | arman
# Processing Record 16 of Set 7 | corrente
# Processing Record 17 of Set 7 | karauzyak
# City not found. Skipping...
# Processing Record 18 of Set 7 | tambun
# Processing Record 19 of Set 7 | birin
# Processing Record 20 of Set 7 | gazanjyk
# Processing Record 21 of Set 7 | san patricio
# Processing Record 22 of Set 7 | amot
# Processing Record 23 of Set 7 | mon
# Processing Record 24 of Set 7 | vung tau
# Processing Record 25 of Set 7 | awbari
# Processing Record 26 of Set 7 | khorixas
# Processing Record 27 of Set 7 | zouxian
# City not found. Skipping...
# Processing Record 28 of Set 7 | mabaruma
# Processing Record 29 of Set 7 | henties bay
# Processing Record 30 of Set 7 | miramar
# Processing Record 31 of Set 7 | grand gaube
# Processing Record 32 of Set 7 | kiunga
# Processing Record 33 of Set 7 | kungurtug
# Processing Record 34 of Set 7 | tacoronte
# Processing Record 35 of Set 7 | gualeguaychu
# Processing Record 36 of Set 7 | nizhniy kuranakh
# Processing Record 37 of Set 7 | kimberley
# Processing Record 38 of Set 7 | mecca
# Processing Record 39 of Set 7 | dolzhanskaya
# Processing Record 40 of Set 7 | bilibino
# Processing Record 41 of Set 7 | krasnyy chikoy
# Processing Record 42 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 43 of Set 7 | marsh harbour
# Processing Record 44 of Set 7 | vawkavysk
# Processing Record 45 of Set 7 | lompoc
# Processing Record 46 of Set 7 | camopi
# Processing Record 47 of Set 7 | lagoa
# Processing Record 48 of Set 7 | sorong
# Processing Record 49 of Set 7 | kargasok
# Processing Record 50 of Set 7 | bathsheba
# Processing Record 1 of Set 8 | dicabisagan
# Processing Record 2 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 8 | paamiut
# Processing Record 4 of Set 8 | izhma
# Processing Record 5 of Set 8 | shingu
# Processing Record 6 of Set 8 | sitka
# Processing Record 7 of Set 8 | richards bay
# Processing Record 8 of Set 8 | toronto
# Processing Record 9 of Set 8 | dunedin
# Processing Record 10 of Set 8 | oistins
# Processing Record 11 of Set 8 | iquique
# Processing Record 12 of Set 8 | palmer
# Processing Record 13 of Set 8 | soyo
# Processing Record 14 of Set 8 | aklavik
# Processing Record 15 of Set 8 | erenhot
# Processing Record 16 of Set 8 | miri
# Processing Record 17 of Set 8 | zhanakorgan
# Processing Record 18 of Set 8 | chabahar
# Processing Record 19 of Set 8 | daru
# Processing Record 20 of Set 8 | rio gallegos
# Processing Record 21 of Set 8 | altamira
# Processing Record 22 of Set 8 | comodoro rivadavia
# Processing Record 23 of Set 8 | belaya gora
# Processing Record 24 of Set 8 | flinders
# Processing Record 25 of Set 8 | babati
# Processing Record 26 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 27 of Set 8 | valleyview
# Processing Record 28 of Set 8 | willowmore
# Processing Record 29 of Set 8 | jibuti
# Processing Record 30 of Set 8 | sembe
# Processing Record 31 of Set 8 | ulaangom
# Processing Record 32 of Set 8 | karratha
# Processing Record 33 of Set 8 | broome
# Processing Record 34 of Set 8 | namatanai
# Processing Record 35 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 36 of Set 8 | mitu
# Processing Record 37 of Set 8 | grindavik
# Processing Record 38 of Set 8 | the valley
# Processing Record 39 of Set 8 | constantine
# Processing Record 40 of Set 8 | provideniya
# Processing Record 41 of Set 8 | waipawa
# Processing Record 42 of Set 8 | cuamba
# Processing Record 43 of Set 8 | hamilton
# Processing Record 44 of Set 8 | zhangjiakou
# Processing Record 45 of Set 8 | thompson
# Processing Record 46 of Set 8 | byron bay
# Processing Record 47 of Set 8 | moerai
# Processing Record 48 of Set 8 | daxian
# City not found. Skipping...
# Processing Record 49 of Set 8 | santa rosa
# Processing Record 50 of Set 8 | middle island
# Processing Record 1 of Set 9 | ayan
# Processing Record 2 of Set 9 | prosvet
# Processing Record 3 of Set 9 | mareeba
# Processing Record 4 of Set 9 | uarini
# Processing Record 5 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 6 of Set 9 | mehamn
# Processing Record 7 of Set 9 | margate
# Processing Record 8 of Set 9 | boden
# Processing Record 9 of Set 9 | khonsa
# Processing Record 10 of Set 9 | nizhnyaya omka
# Processing Record 11 of Set 9 | vizinga
# Processing Record 12 of Set 9 | mayo
# Processing Record 13 of Set 9 | constitucion
# Processing Record 14 of Set 9 | altay
# Processing Record 15 of Set 9 | dieppe
# Processing Record 16 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 17 of Set 9 | langenau
# Processing Record 18 of Set 9 | imbituba
# Processing Record 19 of Set 9 | quelimane
# Processing Record 20 of Set 9 | leningradskiy
# Processing Record 21 of Set 9 | toora-khem
# Processing Record 22 of Set 9 | buala
# Processing Record 23 of Set 9 | rocha
# Processing Record 24 of Set 9 | falealupo
# City not found. Skipping...
# Processing Record 25 of Set 9 | huarmey
# Processing Record 26 of Set 9 | new ulm
# Processing Record 27 of Set 9 | fortuna
# Processing Record 28 of Set 9 | rongcheng
# Processing Record 29 of Set 9 | vadinsk
# Processing Record 30 of Set 9 | kaeo
# Processing Record 31 of Set 9 | paucartambo
# City not found. Skipping...
# Processing Record 32 of Set 9 | teahupoo
# Processing Record 33 of Set 9 | lima
# Processing Record 34 of Set 9 | turukhansk
# Processing Record 35 of Set 9 | souillac
# Processing Record 36 of Set 9 | baculin
# Processing Record 37 of Set 9 | cambridge
# Processing Record 38 of Set 9 | urdoma
# Processing Record 39 of Set 9 | santa maria
# Processing Record 40 of Set 9 | calhoun
# Processing Record 41 of Set 9 | luwingu
# Processing Record 42 of Set 9 | orange cove
# Processing Record 43 of Set 9 | victoria
# Processing Record 44 of Set 9 | carutapera
# Processing Record 45 of Set 9 | chara
# Processing Record 46 of Set 9 | uuemoisa
# Processing Record 47 of Set 9 | ballina
# Processing Record 48 of Set 9 | kabo
# Processing Record 49 of Set 9 | nioro
# Processing Record 50 of Set 9 | changping
# Processing Record 1 of Set 10 | makung
# City not found. Skipping...
# Processing Record 2 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 3 of Set 10 | doha
# Processing Record 4 of Set 10 | polis
# Processing Record 5 of Set 10 | morristown
# Processing Record 6 of Set 10 | bosaso
# Processing Record 7 of Set 10 | chengmai
# City not found. Skipping...
# Processing Record 8 of Set 10 | puerto escondido
# Processing Record 9 of Set 10 | chulym
# Processing Record 10 of Set 10 | ahipara
# Processing Record 11 of Set 10 | sao sebastiao
# Processing Record 12 of Set 10 | chumikan
# Processing Record 13 of Set 10 | port augusta
# Processing Record 14 of Set 10 | ancud
# Processing Record 15 of Set 10 | vredendal
# Processing Record 16 of Set 10 | jinchang
# Processing Record 17 of Set 10 | benguela
# Processing Record 18 of Set 10 | beyneu
# Processing Record 19 of Set 10 | araceli
# Processing Record 20 of Set 10 | coos bay
# Processing Record 21 of Set 10 | tabarqah
# City not found. Skipping...
# Processing Record 22 of Set 10 | port-gentil
# Processing Record 23 of Set 10 | pacific grove
# Processing Record 24 of Set 10 | jiazi
# Processing Record 25 of Set 10 | port hardy
# Processing Record 26 of Set 10 | safwah
# City not found. Skipping...
# Processing Record 27 of Set 10 | mamedkala
# Processing Record 28 of Set 10 | verkhoshizhemye
# Processing Record 29 of Set 10 | barahona
# Processing Record 30 of Set 10 | saint anthony
# Processing Record 31 of Set 10 | kavieng
# Processing Record 32 of Set 10 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 33 of Set 10 | muli
# Processing Record 34 of Set 10 | deputatskiy
# Processing Record 35 of Set 10 | ndago
# Processing Record 36 of Set 10 | libertador general san martin
# Processing Record 37 of Set 10 | takoradi
# Processing Record 38 of Set 10 | cristalina
# Processing Record 39 of Set 10 | tautira
# Processing Record 40 of Set 10 | plouzane
# Processing Record 41 of Set 10 | jimo
# Processing Record 42 of Set 10 | san cristobal
# Processing Record 43 of Set 10 | ipameri
# Processing Record 44 of Set 10 | kerrville
# Processing Record 45 of Set 10 | aksu
# Processing Record 46 of Set 10 | sechura
# Processing Record 47 of Set 10 | prinos
# Processing Record 48 of Set 10 | praxedis guerrero
# Processing Record 49 of Set 10 | camocim
# Processing Record 50 of Set 10 | skovde
# City not found. Skipping...
# Processing Record 1 of Set 11 | invermere
# Processing Record 2 of Set 11 | bellinzona
# Processing Record 3 of Set 11 | ribeirao branco
# Processing Record 4 of Set 11 | alofi
# Processing Record 5 of Set 11 | tazovskiy
# Processing Record 6 of Set 11 | johvi
# Processing Record 7 of Set 11 | hay river
# Processing Record 8 of Set 11 | sayyan
# Processing Record 9 of Set 11 | banjarmasin
# Processing Record 10 of Set 11 | manakara
# Processing Record 11 of Set 11 | balaipungut
# Processing Record 12 of Set 11 | racale
# Processing Record 13 of Set 11 | almeria
# Processing Record 14 of Set 11 | atakpame
# Processing Record 15 of Set 11 | ishigaki
# Processing Record 16 of Set 11 | grand-lahou
# Processing Record 17 of Set 11 | rawson
# Processing Record 18 of Set 11 | yashkul
# Processing Record 19 of Set 11 | donja medjidja
# City not found. Skipping...
# Processing Record 20 of Set 11 | jumla
# Processing Record 21 of Set 11 | kalabagh
# Processing Record 22 of Set 11 | korla
# Processing Record 23 of Set 11 | olafsvik
# Processing Record 24 of Set 11 | salina
# Processing Record 25 of Set 11 | asosa
# Processing Record 26 of Set 11 | tahoua
# Processing Record 27 of Set 11 | sept-iles
# Processing Record 28 of Set 11 | zheleznogorsk
# Processing Record 29 of Set 11 | kaniama
# Processing Record 30 of Set 11 | ngunguru
# Processing Record 31 of Set 11 | barnaul
# Processing Record 32 of Set 11 | hirado
# Processing Record 33 of Set 11 | galle
# Processing Record 34 of Set 11 | impfondo
# Processing Record 35 of Set 11 | natal
# Processing Record 36 of Set 11 | hargeysa
# Processing Record 37 of Set 11 | hami
# Processing Record 38 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 39 of Set 11 | gornopravdinsk
# Processing Record 40 of Set 11 | nurota
# Processing Record 41 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 42 of Set 11 | tahe
# Processing Record 43 of Set 11 | hanyang
# Processing Record 44 of Set 11 | hohhot
# Processing Record 45 of Set 11 | cascais
# Processing Record 46 of Set 11 | mehran
# Processing Record 47 of Set 11 | funchal
# Processing Record 48 of Set 11 | temir
# Processing Record 49 of Set 11 | cangucu
# Processing Record 50 of Set 11 | tolaga bay
# Processing Record 1 of Set 12 | vila
# Processing Record 2 of Set 12 | nautla
# Processing Record 3 of Set 12 | dondo
# Processing Record 4 of Set 12 | pombas
# Processing Record 5 of Set 12 | mangan
# Processing Record 6 of Set 12 | ambilobe
# Processing Record 7 of Set 12 | tigil
# Processing Record 8 of Set 12 | mandan
# Processing Record 9 of Set 12 | roma
# Processing Record 10 of Set 12 | matagami
# Processing Record 11 of Set 12 | matara
# Processing Record 12 of Set 12 | pativilca
# Processing Record 13 of Set 12 | inta
# Processing Record 14 of Set 12 | yar-sale
# Processing Record 15 of Set 12 | belozerskoye
# Processing Record 16 of Set 12 | pangkalanbuun
# Processing Record 17 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 18 of Set 12 | agar
# Processing Record 19 of Set 12 | guarapari
# Processing Record 20 of Set 12 | severo-yeniseyskiy
# Processing Record 21 of Set 12 | kalispell
# Processing Record 22 of Set 12 | soc trang
# Processing Record 23 of Set 12 | zhigansk
# Processing Record 24 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 25 of Set 12 | eltham
# Processing Record 26 of Set 12 | bairiki
# Processing Record 27 of Set 12 | alyangula
# Processing Record 28 of Set 12 | ntungamo
# Processing Record 29 of Set 12 | tam ky
# Processing Record 30 of Set 12 | sao gotardo
# Processing Record 31 of Set 12 | marquette
# Processing Record 32 of Set 12 | manado
# Processing Record 33 of Set 12 | kingston
# Processing Record 34 of Set 12 | pell city
# Processing Record 35 of Set 12 | khandyga
# Processing Record 36 of Set 12 | hammerfest
# Processing Record 37 of Set 12 | shelopugino
# Processing Record 38 of Set 12 | ures
# Processing Record 39 of Set 12 | alice springs
# Processing Record 40 of Set 12 | whitehorse
# Processing Record 41 of Set 12 | haines junction
# Processing Record 42 of Set 12 | fier
# Processing Record 43 of Set 12 | svetlyy
# Processing Record 44 of Set 12 | chernyshevskiy
# Processing Record 45 of Set 12 | samarai
# Processing Record 46 of Set 12 | sumbe
# Processing Record 47 of Set 12 | nkoteng
# Processing Record 48 of Set 12 | shimoda
# Processing Record 49 of Set 12 | dubna
# Processing Record 50 of Set 12 | ust-koksa
# Processing Record 1 of Set 13 | road town
# Processing Record 2 of Set 13 | gurupi
# Processing Record 3 of Set 13 | hagi
# Processing Record 4 of Set 13 | gamba
# Processing Record 5 of Set 13 | durban
# Processing Record 6 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 7 of Set 13 | fort saint john
# City not found. Skipping...
# Processing Record 8 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 9 of Set 13 | yumen
# Processing Record 10 of Set 13 | marsa matruh
# Processing Record 11 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 12 of Set 13 | mackay
# Processing Record 13 of Set 13 | karasjok
# Processing Record 14 of Set 13 | ikirun
# Processing Record 15 of Set 13 | xacmaz
# Processing Record 16 of Set 13 | chiredzi
# Processing Record 17 of Set 13 | keti bandar
# Processing Record 18 of Set 13 | kuala terengganu
# Processing Record 19 of Set 13 | longview
# Processing Record 20 of Set 13 | belyy yar
# Processing Record 21 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 13 | walvis bay
# Processing Record 23 of Set 13 | zacualpan
# Processing Record 24 of Set 13 | moussoro
# Processing Record 25 of Set 13 | anloga
# Processing Record 26 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 13 | padang
# Processing Record 28 of Set 13 | uhlove
# Processing Record 29 of Set 13 | mayumba
# Processing Record 30 of Set 13 | olaine
# Processing Record 31 of Set 13 | aiquile
# Processing Record 32 of Set 13 | wanning
# Processing Record 33 of Set 13 | jonesboro
# Processing Record 34 of Set 13 | codrington
# Processing Record 35 of Set 13 | sumenep
# Processing Record 36 of Set 13 | general pico
# Processing Record 37 of Set 13 | ketchikan
# Processing Record 38 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 39 of Set 13 | bantogon
# Processing Record 40 of Set 13 | nangong
# Processing Record 41 of Set 13 | yarim
# Processing Record 42 of Set 13 | maniitsoq
# Processing Record 43 of Set 13 | muswellbrook
# Processing Record 44 of Set 13 | yialos
# City not found. Skipping...
# Processing Record 45 of Set 13 | iberia
# Processing Record 46 of Set 13 | hualmay
# Processing Record 47 of Set 13 | oriximina
# Processing Record 48 of Set 13 | fianarantsoa
# Processing Record 49 of Set 13 | saint-joseph
# Processing Record 50 of Set 13 | martinsburg
# Processing Record 1 of Set 14 | khadyzhensk
# Processing Record 2 of Set 14 | urucara
# Processing Record 3 of Set 14 | nelson bay
# Processing Record 4 of Set 14 | lillooet
# Processing Record 5 of Set 14 | alta floresta
# Processing Record 6 of Set 14 | durg
# Processing Record 7 of Set 14 | quatre cocos
# Processing Record 8 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 9 of Set 14 | ranong
# Processing Record 10 of Set 14 | manali
# Processing Record 11 of Set 14 | florianopolis
# Processing Record 12 of Set 14 | shelburne
# Processing Record 13 of Set 14 | valley city
# Processing Record 14 of Set 14 | faya
# Processing Record 15 of Set 14 | gander
# Processing Record 16 of Set 14 | batticaloa
# Processing Record 17 of Set 14 | uthal
# Processing Record 18 of Set 14 | ginda
# Processing Record 19 of Set 14 | leshukonskoye
# Processing Record 20 of Set 14 | celestun
# Processing Record 21 of Set 14 | jabiru
# City not found. Skipping...
# Processing Record 22 of Set 14 | kimbe
# Processing Record 23 of Set 14 | dalbandin
# Processing Record 24 of Set 14 | vestmannaeyjar
# Processing Record 25 of Set 14 | los llanos de aridane
# Processing Record 26 of Set 14 | kilmez
# City not found. Skipping...
# Processing Record 27 of Set 14 | olinda
# Processing Record 28 of Set 14 | blackfoot
# Processing Record 29 of Set 14 | conceicao do araguaia
# Processing Record 30 of Set 14 | serebryansk
# Processing Record 31 of Set 14 | beckley
# Processing Record 32 of Set 14 | tapaua
# City not found. Skipping...
# Processing Record 33 of Set 14 | manaus
# Processing Record 34 of Set 14 | bolshaya glushitsa
# Processing Record 35 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 14 | yerofey pavlovich
# Processing Record 37 of Set 14 | komsomolskoye
# Processing Record 38 of Set 14 | yaan
# Processing Record 39 of Set 14 | chunoyar
# Processing Record 40 of Set 14 | liepaja
# Processing Record 41 of Set 14 | alamos
# Processing Record 42 of Set 14 | burkhala
# City not found. Skipping...
# Processing Record 43 of Set 14 | vanimo
# Processing Record 44 of Set 14 | koboko
# Processing Record 45 of Set 14 | oildale
# Processing Record 46 of Set 14 | berdigestyakh
# Processing Record 47 of Set 14 | svetlaya
# Processing Record 48 of Set 14 | sarkand
# Processing Record 49 of Set 14 | acarau
# Processing Record 50 of Set 14 | isangel
# Processing Record 1 of Set 15 | texarkana
# Processing Record 2 of Set 15 | tilichiki
# Processing Record 3 of Set 15 | la ronge
# Processing Record 4 of Set 15 | shasta lake
# Processing Record 5 of Set 15 | soavinandriana
# Processing Record 6 of Set 15 | jiangyou
# Processing Record 7 of Set 15 | namibe
# Processing Record 8 of Set 15 | kuching
# Processing Record 9 of Set 15 | itarema
# Processing Record 10 of Set 15 | lujan
# Processing Record 11 of Set 15 | maryville
# Processing Record 12 of Set 15 | george town
# Processing Record 13 of Set 15 | iacu
# Processing Record 14 of Set 15 | abeche
# Processing Record 15 of Set 15 | luderitz
# Processing Record 16 of Set 15 | ostersund
# Processing Record 17 of Set 15 | maragogi
# Processing Record 18 of Set 15 | bedesa
# Processing Record 19 of Set 15 | aswan
# Processing Record 20 of Set 15 | kedrovyy
# Processing Record 21 of Set 15 | hambantota
# Processing Record 22 of Set 15 | bantry
# Processing Record 23 of Set 15 | kholm
# Processing Record 24 of Set 15 | marfino
# Processing Record 25 of Set 15 | the pas
# Processing Record 26 of Set 15 | parole
# Processing Record 27 of Set 15 | sangar
# Processing Record 28 of Set 15 | sao joao da barra
# Processing Record 29 of Set 15 | dhidhdhoo
# Processing Record 30 of Set 15 | qeshm
# Processing Record 31 of Set 15 | tashtagol
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Carnarvon      AU -24.8667  113.6333     78.53        73          28
# 1      Ushuaia      AR -54.8000  -68.3000     47.82        57          75
# 2       Faanui      PF -16.4833 -151.7500     80.76        74          69
# 3        Kadom      RU  54.5592   42.4675     17.85        95         100
# 4  Pangnirtung      CA  66.1451  -65.7125    -10.01        99         100
# 5        Bluff      NZ -46.6000  168.3333     53.80        86         100
# 6     Sulangan      PH  11.1373  123.7228     80.06        80          97
# 7        Avera      US  33.1940  -82.5271     75.07        59         100
# 8        Dubai      AE  25.2582   55.3047     73.22        52           0
# 9       Kodiak      US  57.7900 -152.4072     40.51        93         100
#
#    Wind Speed Current Description
# 0       10.16    scattered clouds
# 1       21.85       broken clouds
# 2       16.06          light rain
# 3        5.95     overcast clouds
# 4        6.38          light snow
# 5        4.52          light rain
# 6       11.01     overcast clouds
# 7       12.21     overcast clouds
# 8        4.61           clear sky
# 9        8.05                mist

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file,index_label="City_ID")
