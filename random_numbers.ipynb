# %%
# Import the random module.
import random

# %%
# creates random floating point numbers between 0 and 1
random.random()
# Out:
# 0.8696548556963025

# %%
# creates random numbers between the limits specified. in this case 1 and 10
random.randint(1,10)
# Out:
# 1

# %%
# create a list of random numbers between -90 and 89
x = 1
latitudes = []
while x < 1500:
    random_lat = random.randint(-90, 89) + random.random()
    latitudes.append(random_lat)
    x += 1

# %%
latitudes
# Out:
# [11.930364376630735,
#  57.77255133286188,
#  -1.3669767445692074,
#  41.92995808739779,
#  -50.48515819608826,
#  32.07608947283739,
#  -77.2762076737638,
#  15.692569002046246,
#  26.16809126876514,
#  -57.91128548332226,
#  59.5679078285883,
#  -22.811663695889944,
#  -82.90524429371061,
#  -12.172428833291884,
#  65.59010998993179,
#  15.520763372949286,
#  12.218278832569053,
#  -80.84940201027338,
#  88.57067108304233,
#  4.376348745928126,
#  57.28883609199843,
#  -62.35089079051285,
#  6.368728137743133,
#  -68.15627819377407,
#  -1.0508536000892508,
#  -68.33971748614849,
#  -23.319254568612727,
#  -0.09792645400158229,
#  8.771469371461794,
#  38.805760306768015,
#  -38.275670030585125,
#  -46.083152354957605,
#  70.10482900442474,
#  -60.56037934091277,
#  9.753034551774997,
#  -70.97296598123684,
#  46.754697659359984,
#  41.890431614201034,
#  53.603870752266516,
#  -18.920399913887472,
#  56.29005264598844,
#  5.0296814902952764,
#  44.24545247831624,
# ...

# %%
random.randrange(-90, 90, 2)
# Out:
# 64

# %%
# Import the NumPy module.
import numpy as np
# Import timeit.
import timeit

# %%
# %timeit np.random.uniform(-90, 90, size=50)
# Out:
# 2.85 µs ± 6.7 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 1.59 ms ± 2.24 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
